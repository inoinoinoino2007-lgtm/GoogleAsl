# %%
import asyncio
import importlib
import os
import warnings

from google.adk.agents import Agent
from google.adk.models.lite_llm import LiteLlm  # For multi-model support
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.tools.tool_context import ToolContext
from google.genai import types  # For creating message Content/Parts
from IPython.display import HTML, Markdown, display

# Ignore all warnings
warnings.filterwarnings("ignore")

import logging

logging.basicConfig(level=logging.ERROR)

# Set `PATH` to include the directory containing ADK command
# PATH = %env PATH
# %env PATH=/home/jupyter/.local/bin:{PATH}

# %%
LOCATION = "us-central1"
os.environ["GOOGLE_CLOUD_LOCATION"] = LOCATION
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "TRUE"  # Use Vertex AI API
os.environ["GOOGLE_CLOUD_PROJECT"] = "qwiklabs-asl-01-81978728819b"  # Use Vertex AI API

# %%
# %%bash
# # -p オプションを付けて adk_agents/ ディレクトリを作成します。
# # -p は、ディレクトリが既に存在してもエラーを出さず、親ディレクトリも同時に作成します。
# mkdir -p adk_agents

# %%
# %%bash
# echo > adk_agents/.env "GOOGLE_CLOUD_LOCATION=$GOOGLE_CLOUD_LOCATION
# GOOGLE_CLOUD_PROJECT=$GOOGLE_CLOUD_PROJECT
#
# GOOGLE_GENAI_USE_VERTEXAI=$GOOGLE_GENAI_USE_VERTEXAI
# "

# %%
MODEL = "gemini-2.0-flash"

# %%
# %%bash
# # 必要なディレクトリ構造をすべて作成します。
# # -p オプションは、パスの中間にあるディレクトリもすべて作成し、
# # すでに存在してもエラーを出さないため安全です。
# mkdir -p ./adk_agents/agent1_news_collector

# %%
# %%writefile ./adk_agents/agent1_news_collector/tools.py

import pandas as pd
from GoogleNews import GoogleNews # GoogleNewsなどの必要なライブラリもインポート
import json
from google import genai
from google.genai.errors import APIError

import logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)


def fetch_stock_news_from_google_news(query:str) -> dict:
    """Retrieves recent news articles related to a specific financial or market query from Google News.

    Args:
        query (str): The keyword or phrase for the search (e.g., "Toyota stock forecast", "Nikkei 225 news").
        
    Returns:
        dict: A Data dictionary containing the collected news data (e.g., Title, Summary, Source, URL).
    """
    print(f"✅ 検索キーワード: '{query}' でGoogle Newsを検索中...")

    # GoogleNewsオブジェクトを初期化
    googlenews = GoogleNews(lang='en', region='US') # 日本語、日本リージョンで設定
    # googlenews = GoogleNews(lang='ja', region='ja') # 日本語、日本リージョンで設定
    # 検索クエリを設定し、指定ページ数まで結果を取得
    googlenews.search(query)
    
    # 結果を取得
    results = googlenews.results()
    
    news_data = {} # 辞書型として初期化
    article_index = 1 # 記事のキーとして使用するカウンター

    for item in results:
        # 必要な情報を抽出し、一時的なディクショナリ（記事データ）を作成
        article_dict = {
            'title': item.get('title'),
            'source': item.get('publisher'),
            'date': item.get('date'),
            'url': item.get('link'),
            'summary': item.get('desc')
        }
    
        # 💡 修正点: .append() の代わりに、連番をキーとしてディクショナリに保存
        news_data[f'article_{article_index}'] = article_dict
        
        # 次のキーのためにカウンターを増やす
        article_index += 1
    
    if not news_data:
        print("❌ 該当するニュース記事が見つかりませんでした。")
        return {
            "status": "failed",
            "count": 0,
            "message": "No news articles found for the query.",
            "articles": []
        }

    print(f"✅ 合計 {len(news_data)} 件の記事が見つかりました。")
    print("#######################",news_data)
    # ファイルに書き込む
    with open("./data.json", 'w', encoding='utf-8') as f:
        # indent=4 で整形して書き込むと、ファイルが読みやすくなります
        json.dump(news_data, f)

    return {"status": "OK"}


def predict_index(target_index: str, query: str) -> dict:
    """The minimum function required to analyze news articles and have Gemini generate a prediction and its rationale."""
    # ----------------------------------------------------
    # 💡 注意: clientは通常モジュールレベルで一度だけ初期化します
    # ファイルを読み込む
    with open("./data.json", 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    print("######data",data)
    try:
        client = genai.Client()
        print("Gemini Clientの初期化しました")
    except Exception as e:
        # 環境変数または認証情報に問題がある可能性があります
        print(f"Gemini Clientの初期化に失敗しました: {e}")
        client = None
    # ----------------------------------------------------
    # 1. 最小限の初期チェック
    if client is None:
        return {"status": "error", "message": "Client not initialized."}

    if not query:
        return {"status": "data_insufficient", "message": "No news data provided."}

    
    # 3. 最小限のプロンプトと必須JSON形式
    prompt = f"""
    Based *only* on the provided news articles in the {data}, analyze the sentiment and predict the closing direction for the **{target_index}** index. 
    Predict the close-price for the **{target_index}** index.
    Output the result strictly in the required JSON format.

    News Articles:
    ---
    {data}
    ---

    Required JSON Format:
    {{
      "predicted_close_price": <float or current index value>,
      "market_sentiment": "<Bullish|Bearish|Neutral>",
      "analysis_basis": "<Concise summary of the market drivers, max 50 words>"
    }}
    """
    
    # 4. API呼び出しと最小限のエラー処理
    try:
        response = client.models.generate_content(
            model='gemini-2.5-flash',
            contents=prompt,
            config={"response_mime_type": "application/json"}
        )
        
        # JSON応答をパース
        llm_analysis = json.loads(response.text)
        
        # 💡 デバッグ用: 応答が成功した場合、Geminiの解析結果をそのまま返して構造を確認
        return {
            "prediction_status": "success",
            "target_index": target_index,
            "llm_output": llm_analysis # 解析結果全体を返して確認
        }

    except Exception as e:
        # ネットワーク、認証、JSONパースなど、全てのエラーをキャッチ
        return {
            "prediction_status": "runtime_error",
            "message": f"An unexpected error occurred during API call or JSON parsing: {type(e).__name__}: {str(e)}",
            "error_type": type(e).__name__
        }
# Out:
# Overwriting ./adk_agents/agent1_news_collector/tools.py

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
# %%writefile ./adk_agents/agent1_news_collector/agent.py
from google.adk.agents import Agent
from google.adk.tools import AgentTool

from .tools import fetch_stock_news_from_google_news, predict_index

google_search_agent = Agent(
    name="google_search_agent",
    model="gemini-2.0-flash",
    instruction="Retrieves recent news articles from Google News.",
    tools=[fetch_stock_news_from_google_news]
)

predict_agent = Agent(
    name="predict_index_price_agent",
    model="gemini-2.0-flash",
    instruction="Predict the closing price of a stock index based on news articles.",
    tools=[predict_index]
)

root_agent = Agent(
    name="news_agent_v1",
    model="gemini-2.0-flash", # Can be a string for Gemini or a LiteLlm object
    description="Analyzes market news to predict stock index trends.",
    instruction="You are a helpful finance assistant. When the user asks for a prediction about a specific index(like DOW or N225), use the 'predict_agent' tool to provide a prediction.",

    tools=[
        
        AgentTool(google_search_agent, skip_summarization=False),
        AgentTool(predict_agent, skip_summarization=False)
        
    ]
)
# Out:
# Overwriting ./adk_agents/agent1_news_collector/agent.py

# %%
from google.adk.agents.sequential_agent import SequentialAgent

# %%
import pandas as pd
from GoogleNews import GoogleNews # GoogleNewsなどの必要なライブラリもインポート
import json
from google import genai
from google.genai.errors import APIError

import logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)


def fetch_stock_news_from_google_news(query:str) -> dict:
    """Retrieves recent news articles related to a specific financial or market query from Google News.

    Args:
        query (str): The keyword or phrase for the search (e.g., "Toyota stock forecast", "Nikkei 225 news").
        
    Returns:
        dict: A Data dictionary containing the collected news data (e.g., Title, Summary, Source, URL).
    """
    print(f"✅ 検索キーワード: '{query}' でGoogle Newsを検索中...")

    # GoogleNewsオブジェクトを初期化
    googlenews = GoogleNews(lang='en', region='US') # 日本語、日本リージョンで設定
    # googlenews = GoogleNews(lang='ja', region='ja') # 日本語、日本リージョンで設定
    # 検索クエリを設定し、指定ページ数まで結果を取得
    googlenews.search(query)
    
    # 結果を取得
    results = googlenews.results()
    
    news_data = {} # 辞書型として初期化
    article_index = 1 # 記事のキーとして使用するカウンター

    for item in results:
        # 必要な情報を抽出し、一時的なディクショナリ（記事データ）を作成
        article_dict = {
            'title': item.get('title'),
            'source': item.get('publisher'),
            'date': item.get('date'),
            'url': item.get('link'),
            'summary': item.get('desc')
        }
    
        # 💡 修正点: .append() の代わりに、連番をキーとしてディクショナリに保存
        news_data[f'article_{article_index}'] = article_dict
        
        # 次のキーのためにカウンターを増やす
        article_index += 1
    
    if not news_data:
        print("❌ 該当するニュース記事が見つかりませんでした。")
        return {
            "status": "failed",
            "count": 0,
            "message": "No news articles found for the query.",
            "articles": []
        }

    print(f"✅ 合計 {len(news_data)} 件の記事が見つかりました。")
    print("#######################",news_data)
    # ファイルに書き込む
    with open("./data.json", 'w', encoding='utf-8') as f:
        # indent=4 で整形して書き込むと、ファイルが読みやすくなります
        json.dump(news_data, f)

    return {"status": "OK"}


def predict_index(target_index: str, query: str) -> dict:
    """The minimum function required to analyze news articles and have Gemini generate a prediction and its rationale."""
    # ----------------------------------------------------
    # 💡 注意: clientは通常モジュールレベルで一度だけ初期化します
    # ファイルを読み込む
    with open("./data.json", 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    print("######data",data)
    try:
        client = genai.Client()
        print("Gemini Clientの初期化しました")
    except Exception as e:
        # 環境変数または認証情報に問題がある可能性があります
        print(f"Gemini Clientの初期化に失敗しました: {e}")
        client = None
    # ----------------------------------------------------
    # 1. 最小限の初期チェック
    if client is None:
        return {"status": "error", "message": "Client not initialized."}

    if not query:
        return {"status": "data_insufficient", "message": "No news data provided."}

    
    # 3. 最小限のプロンプトと必須JSON形式
    prompt = f"""
    Based *only* on the provided news articles in the {data}, analyze the sentiment and predict the closing direction for the **{target_index}** index. 
    Predict the close-price for the **{target_index}** index.
    Output the result strictly in the required JSON format.

    News Articles:
    ---
    {data}
    ---

    Required JSON Format:
    {{
      "predicted_close_price": <float or current index value>,
      "market_sentiment": "<Bullish|Bearish|Neutral>",
      "analysis_basis": "<Concise summary of the market drivers, max 50 words>"
    }}
    """
    
    # 4. API呼び出しと最小限のエラー処理
    try:
        response = client.models.generate_content(
            model='gemini-2.5-flash',
            contents=prompt,
            config={"response_mime_type": "application/json"}
        )
        
        # JSON応答をパース
        llm_analysis = json.loads(response.text)
        
        # 💡 デバッグ用: 応答が成功した場合、Geminiの解析結果をそのまま返して構造を確認
        return {
            "prediction_status": "success",
            "target_index": target_index,
            "llm_output": llm_analysis # 解析結果全体を返して確認
        }

    except Exception as e:
        # ネットワーク、認証、JSONパースなど、全てのエラーをキャッチ
        return {
            "prediction_status": "runtime_error",
            "message": f"An unexpected error occurred during API call or JSON parsing: {type(e).__name__}: {str(e)}",
            "error_type": type(e).__name__
        }
    



google_search_agent = Agent(
    name="google_search_agent",
    model="gemini-2.0-flash",
    instruction="Retrieves recent news articles from Google News.",
    tools=[fetch_stock_news_from_google_news]
)

predict_agent = Agent(
    name="predict_index_price_agent",
    model="gemini-2.0-flash",
    instruction="Predict the closing price of a stock index based on news articles.",
    tools=[predict_index]
)

code_pipeline_agent = SequentialAgent(
name="CodePipelineAgent",
sub_agents=[google_search_agent, predict_agent],
description="Executes a sequence of code writing, reviewing, and refactoring."
)
# The agents will run in the order provided: Writer -> Reviewer -> Refactorer

# For ADK tools compatibility, the root agent must be named `root_agent`
root_agent = code_pipeline_agent

# %%
from adk_agents.agent1_news_collector import agent
from adk_agents.agent1_news_collector import tools

importlib.reload(agent)  # Force reload
importlib.reload(tools)  # Force reload

# Example tool usage (optional test)
print(agent.fetch_stock_news_from_google_news("Dow jones"))


print(agent.predict_index("Dow jones","US stock market today: Nasdaq dropped 1.9%, S&P 500 lost 1.1%, Dow slipped 0.8% — What led to Wall Street turning red and why Tesla, Nvidia, Amazon, and Palantir sank"))
# Out:
# ✅ 検索キーワード: 'Dow jones' でGoogle Newsを検索中...
# ✅ 合計 10 件の記事が見つかりました。
# ####################### {'article_1': {'title': 'Stock market today: Dow, S&P 500, Nasdaq futures rise with government shutdown in sharp focus', 'source': None, 'date': '4 minutes ago', 'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-futures-rise-with-government-shutdown-in-sharp-focus-002422241.html&ved=2ahUKEwijh_fqq-aQAxV8G9AFHVeAOgYQxfQBegQIARAC&usg=AOvVaw2lNeIyIzpUOZkOdafiPCJJ', 'summary': 'Stock futures have risen ahead of a week that investors hope will mark the end of the longest government shutdown in US history.'}, 'article_2': {'title': 'Stock futures rise on hope for a deal to end the government shutdown: Live updates', 'source': None, 'date': '0 minutes ago', 'url': 'https://www.cnbc.com/2025/11/09/stock-market-today-live-updates.html&ved=2ahUKEwijh_fqq-aQAxV8G9AFHVeAOgYQxfQBegQIBRAC&usg=AOvVaw34WOl15lvoe_YgfyeeSKNO', 'summary': 'Stock futures rose after some signs of progress among congressional lawmakers over the weekend to end the historic U.S. government shutdown.'}, 'article_3': {'title': 'Dow Jones Futures Climb Amid Shutdown Deal; Nvidia Among Top Buys', 'source': None, 'date': '1 hour ago', 'url': 'https://www.el-balad.com/6761639&ved=2ahUKEwijh_fqq-aQAxV8G9AFHVeAOgYQxfQBeg
# Gemini Clientの初期化しました
# {'prediction_status': 'success', 'target_index': 'Dow jones', 'llm_output': {'predicted_close_price': 'current index value', 'market_sentiment': 'Bullish', 'analysis_basis': 'Dow futures are rising due to widespread optimism for an imminent deal to end the government shutdown, despite earlier reports of market slips.'}}

# %%
APP_NAME = "stocks_market_app"
USER_ID = "user_1"
SESSION_ID = "session_010"  # Using a fixed ID for simplicity

# %%
session_service = InMemorySessionService()

# Create the specific session where the conversation will happen
session = await session_service.create_session(
    app_name=APP_NAME, user_id=USER_ID, session_id=SESSION_ID
)

# %%
runner = Runner(
    agent=agent.root_agent,  # The agent we want to run
    app_name=APP_NAME,  # Associates runs with our app
    session_service=session_service,  # Uses our session manager
)

# %%
async def call_agent_async(query: str, runner, user_id, session_id):
    """Sends a query to the agent and prints the final response."""
    print(f"\n>>> User Query: {query}")

    content = types.Content(role="user", parts=[types.Part(text=query)])

    final_response_text = "Agent did not produce a final response."  # Default

    # Key Concept: run_async executes the agent logic and yields Events.
    # We iterate through events to find the final answer.
    async for event in runner.run_async(
        user_id=user_id, session_id=session_id, new_message=content
    ):
        # You can uncomment the line below to see *all* events during execution
        # print(f"  [Event] Author: {event.author}, Type: {type(event).__name__}, Final: {event.is_final_response()}, Content: {event.content}")

        # Key Concept: is_final_response() marks the concluding message for the turn.
        if event.is_final_response():
            if event.content and event.content.parts:
                # Assuming text response in the first part
                final_response_text = event.content.parts[0].text
            elif (
                event.actions and event.actions.escalate
            ):  # Handle potential errors/escalations
                final_response_text = f"Agent escalated: {event.error_message or 'No specific message.'}"
            # Add more checks here if needed (e.g., specific error codes)
            break  # Stop processing events once the final response is found

    print(f"<<< Agent Response: {final_response_text}")

# %%
await call_agent_async(
    "Search today's stock market important news,and then  predict today's DOW Jones-close-price",
    runner=runner,
    user_id=USER_ID,
    session_id=SESSION_ID,
)
# Out:
# >>> User Query: Search today's stock market important news,and then  predict today's DOW Jones-close-price
# ✅ 検索キーワード: 'today's stock market important news' でGoogle Newsを検索中...
# ✅ 合計 10 件の記事が見つかりました。
# ####################### {'article_1': {'title': 'Full Stock Market News from 2025-11-09', 'source': None, 'date': '5 minutes ago', 'url': 'https://www.stocktitan.net/news/2025-11-09/&ved=2ahUKEwjo2dzFteaQAxU28MkDHWInF-gQxfQBegQIARAC&usg=AOvVaw1WKX2iozkKlSzfAUJCbIMM', 'summary': 'Explore comprehensive stock market news from 2025-11-09. Read about the latest press releases, financial news, and business development from leading public...'}, 'article_2': {'title': 'Stock Market Today: Russell 2000, Dow, and S&P 500 Muscle Big Comeback As Tech Selloff Abates', 'source': None, 'date': '2 days ago', 'url': 'https://www.thestreet.com/latest-news/stock-market-today-u-s-stock-futures-rise-after-week-long-tech-struggle&ved=2ahUKEwjo2dzFteaQAxU28MkDHWInF-gQxfQBeg
ved=2ahUKEwjo2dzFteaQAxU28MkDHWInF-gQxfQBegQICRAC&usg=AOvVaw2wCfkbj_wS9Q6mUsZKxLoW', 'summary': 'Eyes are on the latest flurry of earnings after a record-setting session for the Dow.'}, 'article_8': {'title': 'Stock Market News, Oct. 21, 2025: Dow scores fresh record after strong 3M, Coca-Cola earnings; S&P 500 ends flat and Nasdaq finishes lower; Netflix earnings on tap', 'source': None, 'date': '3 weeks ago', 'url': 'https://www.marketwatch.com/livecoverage/stock-market-today-dow-sp500-nasdaq-shy-of-records-treasury-yield-4-percent-netflix-earnings%3Fgaa_at%3Deafs%26gaa_n%3DAWEtsqeseMaIY35ST_Qjm-M_N4PYAzKl8p6_ZD-9j3gYTS8SC9Uvqn9djKsj%26gaa_ts%3D6911418b%26gaa_sig%3DuB_A8fdtLlMZsv5rLiwabc03gwxvDEuZFY8tSNHnWZGcfehhpt1ucpPH3RqHOrY3sFQ6neJkTWakAweZ-L2tSw%253D%253D&ved=2ahUKEwjo2dzFteaQAxU28MkDHWInF-gQxfQBegQIBxAC&usg=AOvVaw3n4JdihONGqXqTUhZwZqy4', 'summary' ...
# Gemini Clientの初期化しました
# <<< Agent Response: I've analyzed the news and the sentiment seems bullish, but I don't have a predicted closing price for the Dow Jones. Is there anything else I can do?

# %%
# !adk web adk_agents
# Out:
# /home/user/venv1/lib/python3.12/site-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /home/user/venv1/lib/python3.12/site-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [2730]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:52268 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:52268 - "GET /dev-ui/ HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52268 - "GET /dev-ui/chunk-2WH2EVR6.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52268 - "GET /dev-ui/polyfills-B6TNHZQ6.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52268 - "GET /dev-ui/styles-EVMPSV3U.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52272 - "GET /dev-ui/main-OS2OH2S3.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52272 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /dev-ui/adk_favicon.svg HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52272 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /dev-ui/assets/ADK-512-color.svg HTTP/1.1" 304 Not Modified
# 2025-11-10 00:49:09,302 - INFO - adk_web_server.py:605 - New session created: a9c2cd85-f169-40b8-8559-e58801146694
# INFO:     127.0.0.1:52272 - "POST /apps/agent3_stateful_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /builder/app/agent3_stateful_agent?ts=1762735749040 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /apps/agent3_stateful_agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /apps/agent3_stateful_agent/users/user/sessions/a9c2cd85-f169-40b8-8559-e58801146694 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /debug/trace/session/a9c2cd85-f169-40b8-8559-e58801146694 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /apps/agent3_stateful_agent/users/user/sessions HTTP/1.1" 200 OK
# 2025-11-10 00:49:13,463 - INFO - adk_web_server.py:605 - New session created: d8c7093c-49e8-4bfd-bf2f-7221295deb25
# INFO:     127.0.0.1:52272 - "POST /apps/agent1_news_collector/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /builder/app/agent1_news_collector?ts=1762735753197 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /apps/agent1_news_collector/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52272 - "GET /debug/trace/session/d8c7093c-49e8-4bfd-bf2f-7221295deb25 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45338 - "POST /run_sse HTTP/1.1" 200 OK
# 2025-11-10 00:50:16,137 - INFO - envs.py:47 - Loaded .env file for agent1_news_collector at /home/user/kadai_1/kadai1_git/adk_agents/.env
# 2025-11-10 00:50:16,137 - INFO - envs.py:47 - Loaded .env file for agent1_news_collector at /home/user/kadai_1/kadai1_git/adk_agents/.env
# 2025-11-10 00:50:16,550 - INFO - agent_loader.py:127 - Found root_agent in agent1_news_collector.agent
# 2025-11-10 00:50:16,670 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# /home/user/venv1/lib/python3.12/site-packages/google/auth/_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 2025-11-10 00:50:18,109 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-10 00:50:18,109 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 2025-11-10 00:50:18,215 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# /home/user/venv1/lib/python3.12/site-packages/google/auth/_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 2025-11-10 00:50:18,326 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# /home/user/venv1/lib/python3.12/site-packages/google/auth/_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 2025-11-10 00:50:19,545 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-10 00:50:19,621 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-10 00:50:19,621 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ✅ 検索キーワード: 'today's market news' でGoogle Newsを検索中...
# ✅ 合計 10 件の記事が見つかりました。
# ####################### {'article_1': {'title': "Pre-market action: Here's the trade setup for today's session", 'source': None, 'date': '9 minutes ago', 'url': 'https://m.economictimes.com/markets/stocks/news/pre-market-action-heres-the-trade-setup-for-todays-session/articleshow/125205540.cms&ved=2ahUKEwj1uPjSruaQAxXl5ckDHXYBI5kQxfQBegQIAxAC&usg=AOvVaw3EbY_TSSf8OAEOZh5dDYbJ', 'summary': 'Indian markets closed lower amidst weekly volatility, with slight sentiment improvement following positive US-India trade talk indications.'}, 'article_2': {'title': 'Full Stock Market News from 2025-11-09', 'source': None, 'date': '4 minutes ago', 'url': 'https://www.stocktitan.net/news/2025-11-09/&ved=2ahUKEwj1uPjSruaQAxXl5ckDHXYBI5kQxfQBegQIBhAC&usg=AOvVaw3VsP_1R1um4hHWiUhx0Ngv', 'summary': "Stock Market News 2025-11-09. 20 news published. ... Stay ahead of the market with our list of today's most important stock news and financial updates. Whether..."}, 'article_3': {'title': 'Stock market today: Dow, S&P 500, Nasdaq futures rise with government shutdown in sharp focus', 'source': None, 'date': '6 minutes ago', 'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-futures-rise-with-government-shutdown-in-sharp-focus-002422241.html&ved=2ahUKEwj1uPjSruaQAxXl5ckDHXYBI5kQxfQBegQIChAC&usg=AOvVaw2U4mjPLlEqwhTJrbNf9f28', 'summary': 'Stock futures have risen ahead of a week that investors hope will mark the end of the longest government shutdown in US history.'}, 'article_4': {'title': 'Many would-be buyers are frozen out of the housing market', 'source': None, 'date': '5 hours ago', 'url': 'https://www.npr.org/2025/11/09/nx-s1-5600733/many-would-be-buyers-are-frozen-out-of-the-housing-market&ved=2ahUKEwj1uPjSruaQAxXl5ckDHXYBI5kQxfQBegQIAhAC&usg=AOvVaw1SqMEqCmlvwfJnz2MGyUTx', 'summary': 'Only about one in five homes sold in the last year went to a first-time buyer. And the average person buying their first home was 40 years old — a record...'}, 'article_5': {'title': 'How to prepare for a stock market crash — before it’s too late', 'source': None, 'date': '7 hours ago', 'url': 'https://uk.finance.yahoo.com/news/prepare-stock-market-crash-too-080600589.html&ved=2ahUKEwj1uPjSruaQAxXl5ckDHXYBI5kQxfQBegQIARAC&usg=AOvVaw2D0oc6oMgSBFLDSCVPYmN6', 'summary': "You wouldn't sell your house before a downturn in property prices."}, 'article_6': {'title': 'Data-center operator CoreWeave is a stock-market darling. Bears see it as a symbol of the AI infrastructure bubble', 'source': None, 'date': '1 day ago', 'url': 'https://fortune.com/2025/11/08/coreweave-earnings-debt-ai-infrastructure-bubble/&ved=2ahUKEwj1uPjSruaQAxXl5ckDHXYBI5kQxfQBegQIBxAC&usg=AOvVaw1L5VK5AJ2gq2xXLC5Hwjti', 'summary': 'A vast data center in Plano, Texas, is a symbol of the enormous AI infrastructure boom that has boosted stock markets and driven U.S. economic growth over...'}, 'article_7': {'title': 'What Today’s Market Crash Teaches About Long-Term Crypto Growth', 'source': None, 'date': '1 day ago', 'url': 'https://www.livebitcoinnews.com/what-todays-market-crash-teaches-about-long-term-crypto-growth/&ved=2ahUKEwj1uPjSruaQAxXl5ckDHXYBI5kQxfQBegQICRAC&usg=AOvVaw28os1DEmv7wprp6XB1ycMb', 'summary': "Discover what today's market crash reveals about long term investing crypto and how smart investors turn volatility into lasting growth opportunities."}, 'article_8': {'title': 'The New York Stock Exchange | NYSE', 'source': None, 'date': '2 days ago', 'url': 'https://www.nyse.com/index&ved=2ahUKEwj1uPjSruaQAxXl5ckDHXYBI5kQxfQBegQIBRAC&usg=AOvVaw2RsTF6v6zyr2tu_GSYQgvy', 'summary': 'We set the standard with our unparalleled trading platform, enabling entrepreneurs, innovators, and investors to raise the capital they need to change the...'}, 'article_9': {'title': "Watch Can Be Selective in Today's Credit Market: Poli", 'source': None, 'date': '2 days ago', 'url': 'https://www.bloomberg.com/news/videos/2025-11-07/can-be-selective-in-today-s-credit-market-poli-video&ved= ...
# 2025-11-10 00:50:22,180 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# /home/user/venv1/lib/python3.12/site-packages/google/auth/_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 2025-11-10 00:50:23,465 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-10 00:50:23,572 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# /home/user/venv1/lib/python3.12/site-packages/google/auth/_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 2025-11-10 00:50:25,185 - INFO - google_llm.py:186 - Response received from the model.
# INFO:     127.0.0.1:45338 - "GET /debug/trace/session/d8c7093c-49e8-4bfd-bf2f-7221295deb25 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36004 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36004 - "GET /debug/trace/session/d8c7093c-49e8-4bfd-bf2f-7221295deb25 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36004 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:45338 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:43056 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:43062 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:43062 - "GET /debug/trace/ceaa6020-25c7-4e7b-a331-99cb24de86af HTTP/1.1" 200 OK
# INFO:     127.0.0.1:43056 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/ceaa6020-25c7-4e7b-a331-99cb24de86af/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44418 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44424 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44424 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44418 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52942 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52950 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52950 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52942 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52942 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52950 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52950 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52942 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52942 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52950 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52950 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/ceaa6020-25c7-4e7b-a331-99cb24de86af/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52942 - "GET /debug/trace/ceaa6020-25c7-4e7b-a331-99cb24de86af HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44762 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44768 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44768 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:44762 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:46424 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:46438 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:46438 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     127.0.0.1:46424 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57184 - "GET /debug/trace/7672b271-f684-4c54-bdb2-f7066357c9f0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57194 - "GET /apps/agent1_news_collector/users/user/sessions/d8c7093c-49e8-4bfd-bf2f-7221295deb25/events/7672b271-f684-4c54-bdb2-f7066357c9f0/graph HTTP/1.1" 200 OK
# INFO:     Shutting down
# ^C
# INFO:     Finished server process [2730]
# ERROR:    Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 674, in run_until_complete
#     self.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/user/venv1/lib/python3.12/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#   File "/usr/lib/python3.12/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/home/user/venv1/lib/python3.12/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#   File "/usr/lib/python3.12/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/venv1/lib/python3.12/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/home/user/venv1/lib/python3.12/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError
#
#
# Aborted!
